# %% [markdown]
# ## Data Cleaning

# %%
import pandas as pd
df = pd.read_csv(
    "https://raw.githubusercontent.com/TwinkleGhosh/Healthcare_Appointment_no_show_prediction/main/data/cleaned/healthcare_appointments_cleaned.csv"
)

# %%
cleaned_df = df.copy()

# %%
# Check duplicates

cleaned_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Check duplicate Appointment IDs

cleaned_df["AppointmentID"].duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Check invalid ages

# %%
cleaned_df["Age"].describe()
# Out:
# count    110522.000000
# mean         37.089385
# std          23.109780
# min           0.000000
# 25%          18.000000
# 50%          37.000000
# 75%          55.000000
# max         115.000000
# Name: Age, dtype: float64

# %%
cleaned_df[cleaned_df["Age"]<0]
# Out:
#           PatientId  AppointmentID Gender          ScheduledDay  \
# 99832  4.659432e+14        5775010      F  2016-06-06T08:58:13Z
#
#              AppointmentDay  Age Neighbourhood  Scholarship  Hipertension  \
# 99832  2016-06-06T00:00:00Z   -1         ROMÃO            0             0
#
#        Diabetes  Alcoholism  Handcap  SMS_received No-show
# 99832         0           0        0             0      No

# %%
cleaned_df["Age"].min()
# Out:
# 0

# %%
cleaned_df["Age"].max()
# Out:
# 115

# %% [markdown]
# ### Checking categorical values

# %%
cleaned_df["Gender"].value_counts()
# Out:
# Gender
# F    71840
# M    38687
# Name: count, dtype: int64

# %%
cleaned_df["Scholarship"].value_counts()
# Out:
# Scholarship
# 0    99666
# 1    10861
# Name: count, dtype: int64

# %%
cleaned_df["Hipertension"].value_counts()
# Out:
# Hipertension
# 0    88726
# 1    21801
# Name: count, dtype: int64

# %%
cleaned_df["Diabetes"].value_counts()
# Out:
# Diabetes
# 0    102584
# 1      7943
# Name: count, dtype: int64

# %%
cleaned_df["Alcoholism"].value_counts()
# Out:
# Alcoholism
# 0    107167
# 1      3360
# Name: count, dtype: int64

# %%
cleaned_df["Handcap"].value_counts()
# Out:
# Handcap
# 0    108286
# 1      2042
# 2       183
# 3        13
# 4         3
# Name: count, dtype: int64

# %%
cleaned_df["SMS_received"].value_counts()
# Out:
# SMS_received
# 0    75045
# 1    35482
# Name: count, dtype: int64

# %% [markdown]
# ### Patients with Invalid Ages

# %%
cleaned_df[cleaned_df["Age"] == -1].shape[0]
# Out:
# 0

# %%
cleaned_df[cleaned_df["Age"] == -1]
# Out:
#           PatientId  AppointmentID Gender          ScheduledDay  \
# 99832  4.659432e+14        5775010      F  2016-06-06T08:58:13Z
#
#              AppointmentDay  Age Neighbourhood  Scholarship  Hipertension  \
# 99832  2016-06-06T00:00:00Z   -1         ROMÃO            0             0
#
#        Diabetes  Alcoholism  Handcap  SMS_received No-show
# 99832         0           0        0             0      No

# %%
cleaned_df[cleaned_df["Age"] == 115]
# Out:
#           PatientId  AppointmentID Gender               ScheduledDay  \
# 63910  3.196321e+13        5700278      F  2016-05-16 09:17:44+00:00
# 63913  3.196321e+13        5700279      F  2016-05-16 09:17:44+00:00
# 68124  3.196321e+13        5562812      F  2016-04-08 14:29:17+00:00
# 76279  3.196321e+13        5744037      F  2016-05-30 09:44:51+00:00
# 97661  7.482346e+14        5717451      F  2016-05-19 07:57:56+00:00
#
#                   AppointmentDay  Age Neighbourhood  Scholarship  \
# 63910  2016-05-19 00:00:00+00:00  115    ANDORINHAS            0
# 63913  2016-05-19 00:00:00+00:00  115    ANDORINHAS            0
# 68124  2016-05-16 00:00:00+00:00  115    ANDORINHAS            0
# 76279  2016-05-30 00:00:00+00:00  115    ANDORINHAS            0
# 97661  2016-06-03 00:00:00+00:00  115      SÃO JOSÉ            0
#
#        Hypertension  Diabetes  Alcoholism  Handicap  SMS_received No_show  \
# 63910             0         0           0         1             0     Yes
# 63913             0         0           0         1             0     Yes
# 68124             0         0           0         1             0     Yes
# 76279             0         0           0         1             0      No
# 97661             1         0           0         0             1      No
#
#        WaitingDays
# 63910            3
# 63913            3
# 68124           38
# 76279            0
# 97661           15

# %%
cleaned_df[cleaned_df["PatientId"] == 99832]
# Out:
# Empty DataFrame
# Columns: [PatientId, AppointmentID, Gender, ScheduledDay, AppointmentDay, Age, Neighbourhood, Scholarship, Hipertension, Diabetes, Alcoholism, Handcap, SMS_received, No-show]
# Index: []

# %% [markdown]
# ### Fixing the invalid age

# %%
cleaned_df.loc[cleaned_df["Age"] == -1, "Age"] = cleaned_df["Age"].median()

# %%
cleaned_df["Age"].min()
# Out:
# 0

# %%
cleaned_df[cleaned_df["Age"] == -1].shape[0]
# Out:
# 0

# %%
cleaned_df[cleaned_df["PatientId"] == 99832]["Age"]
# Out:
# Series([], Name: Age, dtype: int64)

# %%
cleaned_df = cleaned_df[cleaned_df["Age"] != 115]

# %%
cleaned_df[cleaned_df["Age"] == 115]
# Out:
# Empty DataFrame
# Columns: [PatientId, AppointmentID, Gender, ScheduledDay, AppointmentDay, Age, Neighbourhood, Scholarship, Hypertension, Diabetes, Alcoholism, Handicap, SMS_received, No_show, WaitingDays]
# Index: []

# %%
cleaned_df["Age"].max()
# Out:
# 102

# %% [markdown]
# ## Rename the columns

# %%
cleaned_df = cleaned_df.rename(columns={
    "Hipertension": "Hypertension" ,
    "Handcap": "Handicap",
    "No-show": "No_show"
    })

# %%
cleaned_df.columns
# Out:
# Index(['PatientId', 'AppointmentID', 'Gender', 'ScheduledDay',
#        'AppointmentDay', 'Age', 'Neighbourhood', 'Scholarship', 'Hypertension',
#        'Diabetes', 'Alcoholism', 'Handicap', 'SMS_received', 'No_show'],
#       dtype='str')

# %% [markdown]
# ## Date Conversion

# %%
cleaned_df["ScheduledDay"] = pd.to_datetime(cleaned_df["ScheduledDay"])
cleaned_df["AppointmentDay"] = pd.to_datetime(cleaned_df["AppointmentDay"])

# %%
cleaned_df[["ScheduledDay", "AppointmentDay"]].dtypes
# Out:
# ScheduledDay      datetime64[us, UTC]
# AppointmentDay    datetime64[us, UTC]
# dtype: object

# %%
(cleaned_df["AppointmentDay"] < cleaned_df["ScheduledDay"]).sum()
# Out:
# np.int64(38568)

# %% [markdown]
# ## Compare calendar dates

# %%
scheduled_date = cleaned_df["ScheduledDay"].dt.date
appointment_date = cleaned_df["AppointmentDay"].dt.date

# %%
(scheduled_date > appointment_date).sum()
# Out:
# np.int64(5)

# %% [markdown]
# ## Find and Remove the 5 invalid records

# %%
cleaned_df[scheduled_date > appointment_date]
# Out:
#           PatientId  AppointmentID Gender              ScheduledDay  \
# 27033  7.839273e+12        5679978      M 2016-05-10 10:51:53+00:00
# 55226  7.896294e+12        5715660      F 2016-05-18 14:50:41+00:00
# 64175  2.425226e+13        5664962      F 2016-05-05 13:43:58+00:00
# 71533  9.982316e+14        5686628      F 2016-05-11 13:49:20+00:00
# 72362  3.787482e+12        5655637      M 2016-05-04 06:50:57+00:00
#
#                  AppointmentDay  Age  Neighbourhood  Scholarship  \
# 27033 2016-05-09 00:00:00+00:00   38    RESISTÊNCIA            0
# 55226 2016-05-17 00:00:00+00:00   19  SANTO ANTÔNIO            0
# 64175 2016-05-04 00:00:00+00:00   22     CONSOLAÇÃO            0
# 71533 2016-05-05 00:00:00+00:00   81  SANTO ANTÔNIO            0
# 72362 2016-05-03 00:00:00+00:00    7     TABUAZEIRO            0
#
#        Hypertension  Diabetes  Alcoholism  Handicap  SMS_received No_show
# 27033             0         0           0         1             0     Yes
# 55226             0         0           0         1             0     Yes
# 64175             0         0           0         0             0     Yes
# 71533             0         0           0         0             0     Yes
# 72362             0         0           0         0             0     Yes

# %%
invalid_dates = cleaned_df["ScheduledDay"].dt.date > cleaned_df["AppointmentDay"].dt.date

cleaned_df = cleaned_df[~invalid_dates].copy()

# %%
print("Rows after removing invalid dates:", cleaned_df.shape[0])
# Out:
# Rows after removing invalid dates: 110522

# %%
print(
    "Remaining invalid date records:",
    (
        cleaned_df["ScheduledDay"].dt.date
        > cleaned_df["AppointmentDay"].dt.date
    ).sum()
)
# Out:
# Remaining invalid date records: 0

# %% [markdown]
# ## Create WaitingDays

# %%
cleaned_df["WaitingDays"] = (
    cleaned_df["AppointmentDay"].dt.normalize()
    - cleaned_df["ScheduledDay"].dt.normalize()
).dt.days

# %%
cleaned_df["WaitingDays"].describe()
# Out:
# count    110522.000000
# mean         10.184253
# std          15.255115
# min           0.000000
# 25%           0.000000
# 50%           4.000000
# 75%          15.000000
# max         179.000000
# Name: WaitingDays, dtype: float64

# %%
cleaned_df["WaitingDays"].min()
# Out:
# np.int64(0)

# %%
cleaned_df["WaitingDays"].max()
# Out:
# np.int64(179)

# %% [markdown]
# ## Check the target variable

# %%
cleaned_df["No_show"].value_counts()
# Out:
# No_show
# No     88208
# Yes    22314
# Name: count, dtype: int64

# %%
cleaned_df["No_show"].value_counts(normalize=True) * 100
# Out:
# No_show
# No     79.810354
# Yes    20.189646
# Name: proportion, dtype: float64

# %% [markdown]
# ## Final cleaning check

# %%
cleaned_df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 110522 entries, 0 to 110526
# Data columns (total 15 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       110522 non-null  float64
#  1   AppointmentID   110522 non-null  int64
#  2   Gender          110522 non-null  str
#  3   ScheduledDay    110522 non-null  datetime64[us, UTC]
#  4   AppointmentDay  110522 non-null  datetime64[us, UTC]
#  5   Age             110522 non-null  int64
#  6   Neighbourhood   110522 non-null  str
#  7   Scholarship     110522 non-null  int64
#  8   Hypertension    110522 non-null  int64
#  9   Diabetes        110522 non-null  int64
#  10  Alcoholism      110522 non-null  int64
#  11  Handicap        110522 non-null  int64
#  12  SMS_received    110522 non-null  int64
#  13  No_show         110522 non-null  str
#  14  WaitingDays     110522 non-null  int64
# dtypes: datetime64[us, UTC](2), float64(1), int64(9), str(3)
# memory usage: 13.5 MB

# %%
cleaned_df.isnull().sum()
# Out:
# PatientId         0
# AppointmentID     0
# Gender            0
# ScheduledDay      0
# AppointmentDay    0
# Age               0
# Neighbourhood     0
# Scholarship       0
# Hypertension      0
# Diabetes          0
# Alcoholism        0
# Handicap          0
# SMS_received      0
# No_show           0
# WaitingDays       0
# dtype: int64

# %%
cleaned_df.head()
# Out:
#       PatientId  AppointmentID Gender              ScheduledDay  \
# 0  2.987250e+13        5642903      F 2016-04-29 18:38:08+00:00
# 1  5.589978e+14        5642503      M 2016-04-29 16:08:27+00:00
# 2  4.262962e+12        5642549      F 2016-04-29 16:19:04+00:00
# 3  8.679512e+11        5642828      F 2016-04-29 17:29:31+00:00
# 4  8.841186e+12        5642494      F 2016-04-29 16:07:23+00:00
#
#              AppointmentDay  Age      Neighbourhood  Scholarship  \
# 0 2016-04-29 00:00:00+00:00   62    JARDIM DA PENHA            0
# 1 2016-04-29 00:00:00+00:00   56    JARDIM DA PENHA            0
# 2 2016-04-29 00:00:00+00:00   62      MATA DA PRAIA            0
# 3 2016-04-29 00:00:00+00:00    8  PONTAL DE CAMBURI            0
# 4 2016-04-29 00:00:00+00:00   56    JARDIM DA PENHA            0
#
#    Hypertension  Diabetes  Alcoholism  Handicap  SMS_received No_show  \
# 0             1         0           0         0             0      No
# 1             0         0           0         0             0      No
# 2             0         0           0         0             0      No
# 3             0         0           0         0             0      No
# 4             1         1           0         0             0      No
#
#    WaitingDays
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %% [markdown]
# ## Saving the cleaned dataset

# %%
cleaned_df.to_csv(
    "../data/cleaned/healthcare_appointments_cleaned.csv",
    index=False
)

# %%
import os

os.path.exists("../data/cleaned/healthcare_appointments_cleaned.csv")
# Out:
# True
